# %% [markdown]
# # Geneformer Fine-tuning Demo
#
# This notebook demonstrates fine-tuning Geneformer for cell type classification

# %%
# For Google Colab, uncomment:
# !git clone YOUR_REPO_URL
# %cd geneformer-finetuning
# !pip install -q -r requirements.txt
# !pip install -q --no-deps git+https://huggingface.co/ctheodoris/Geneformer

# %%
import sys
sys.path.insert(0, '..')

from src.utils import load_config
from src.data.dataset_loader import load_dataset, analyze_dataset

# Load config
config = load_config('../configs/config.yaml')

# Load dataset
dataset = load_dataset('../dataset.arrow')
analyze_dataset(dataset)

# %% [markdown]
# See README.md for complete usage instructions
